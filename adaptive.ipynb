# %% [markdown]
# # Adaptive Thresholding Testing

# %%
import cv2 as cv
import os
from matplotlib import pyplot
import numpy as np
# %matplotlib inline
img = cv.cvtColor(cv.imread("C:/Users/Admin/Downloads/img2.png"), cv.COLOR_BGR2GRAY)
ret, thresholded = cv.threshold(img, 0, 1, cv.THRESH_OTSU)
pyplot.imshow(thresholded)

# %%
autoInteresting = np.sum(thresholded == 1)
autoInteresting
# Out:
# 5563911
