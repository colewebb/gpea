# %%
import cv2 as cv
import numpy as np
import os
from matplotlib import pyplot

# %matplotlib inline
pyplot.rcParams['figure.figsize'] = [24, 10]

# %%
os.chdir("C:/Users/Admin/Downloads")
image = cv.cvtColor(cv.imread("img.png"), cv.COLOR_RGB2GRAY)
pyplot.imshow(image)

# %%
image = cv.threshold(image, 0, 1, cv.THRESH_OTSU)[1]
pyplot.imshow(image)

# %%
interestingPixels = np.sum(image == 1)
print(interestingPixels)
# Out:
# 513047

# %%
imageNew = cv.cvtColor(cv.imread("img2.png"), cv.COLOR_RGB2GRAY)
imageNew = cv.threshold(imageNew, 0, 1, cv.THRESH_OTSU)[1]
pyplot.imshow(imageNew)

# %%
print(np.sum(imageNew == 1))
# Out:
# 481291
